# %% [markdown]
# <a href="https://colab.research.google.com/github/baovin/ML_homework/blob/main/Copy_of_Student_Lab2_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# Welcome to this lab!
# At this lab, we will learn how to implement Graph Convolutional Networks (GCN) based on the paper [GCN](https://arxiv.org/pdf/1609.02907.pdf).

# %% [markdown]
# # Exercise

# %% [markdown]
# ## Download data and install packages

# %%
# !gdown --id "1Z748ksOFWZ8WLsy0P8T7eYA6XLVLieX3&export=download"
# !unrar x -Y "/content/lab2.rar" -d "/content/"
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Z748ksOFWZ8WLsy0P8T7eYA6XLVLieX3&export=download
# To: /content/lab2.rar
# 100% 599/599 [00:00<00:00, 2.73MB/s]
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/lab2.rar
#
#   OK
#   OK
# All OK

# %% [markdown]
# ## Packages: Import neccesary packages

# %%
import torch
import torch.nn as nn
import numpy as np
import networkx as nx
import torch.optim as optim
import torch.nn.functional as F
import pandas as pd

# %% [markdown]
# ## Utils: Processing data

# %%
def create_graphs_with_attributes(edgelist_filepath,attributes_filepath):
    graph=nx.read_edgelist(edgelist_filepath,nodetype=int)
    attributes=pd.read_csv(attributes_filepath,index_col=['node'])
    att_values = {a:{'role':b[0],'community':b[1]} for a,b in enumerate(attributes.values)}
    nx.set_node_attributes(graph,att_values)
    return graph


def create_train_test(graph):
    X_train,Y_train,X_test,Y_test=[],[],[],[]
    for node, data in graph.nodes(data=True):
        if data['role'] in ['Administrator','Instructor']:
            X_train.append(node)
            Y_train.append(data['role']=='Administrator')
        elif data['role'] =='Member':
            X_test.append(node)
            Y_test.append(data['community']=='Administrator')
    return np.asarray(X_train),np.asarray(Y_train),np.asarray(X_test),np.asarray(Y_test)



def create_features(graph): # create input features, concatenation of identity matrix and shortest paths to targets
    A = nx.to_numpy_array(graph)
    X_1 = torch.eye(A.shape[0]) # identity matrix
    X_2 = torch.zeros((A.shape[0], 2)) # shortest path to the targets as 2nd input feature
    node_distance_instructor = nx.shortest_path_length(graph, target=33)
    node_distance_administrator = nx.shortest_path_length(graph, target=0)

    for node in graph.nodes():
        X_2[node][0] = node_distance_administrator[node]
        X_2[node][1] = node_distance_instructor[node]

    return torch.cat((X_1,X_2),dim=1)

# %% [markdown]
# ## TO DO: Implement Graph Convolutional Networks (GCN)

# %% [markdown]
# ![GCN.PNG](data:image/png;base64,...)

# %%
from torch.nn.parameter import Parameter

class GCN_layer(nn.Module):
    """
      Define filter layer 1/2 like in the above image
      Calculate A_hat first then,
      Input: adj_matrix with input features X
    """

    def __init__(self, inputs_shape, outputs_shape):
        super(GCN_layer, self).__init__()

        self.W=Parameter(torch.rand(inputs_shape,outputs_shape),requires_grad=True)
        self.bias = Parameter(torch.rand(outputs_shape),requires_grad=True)


    def forward(self, adj_matrix, input_features):
        # TO DO: Calculate A_hat
        # I = torch.eye(adj_matrix).to(adj_matrix.device)  # Identity matrix
        A = torch.from_numpy(adj_matrix)
        I = torch.eye(A.shape[0])
        A_hat = A + I  # A + I

        # Step 2: Compute D^(-1/2)
        D = (torch.sum(A_hat, axis=0))  # Degree matrix
        D_inv_sqrt = torch.diag(torch.pow(D, -1/2))  # D^(-1/2)

        # Step 3: Normalize A_hat
        A_hat = torch.mm(torch.mm(D_inv_sqrt, A_hat), D_inv_sqrt)
        aggregate=torch.mm(A_hat.float(),input_features.float())
        propagate=torch.mm(aggregate,self.W)+self.bias
        return propagate

# %%
class GCN(nn.Module):


    def __init__(self,inputs_shape,outputs_shape,n_classes,activation='Relu'):
        super(GCN, self).__init__()

        self.layer1=GCN_layer(inputs_shape,outputs_shape)
        self.layer2=GCN_layer(outputs_shape,n_classes)


        if activation =='Tanh':
            self.activation = nn.Tanh()
        elif activation=='Sigmoid':
            self.activation = nn.Sigmoid()
        elif activation=='Softmax':
            self.activation=nn.Softmax()
        elif activation=='Relu':
            self.activation=nn.ReLU()

        self.softmax=nn.Softmax()


    def forward(self,adj_matrix,input_features):
        # TO DO: Define output for each layer. Please look at the method in the picture above
        x=self.layer1(adj_matrix,input_features)
        x=self.activation(x)
        x=self.layer2(adj_matrix,x)
        x=self.softmax(x)

        return x

# %%
import torch
from sklearn.metrics import classification_report
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import networkx as nx


graph=create_graphs_with_attributes('lab2_edgelist.txt','lab2_attributes.csv')
A = np.array(nx.to_numpy_array(graph)) # adjadjency matrix

class Trainer():
    def __init__(self,model,optimizer,loss_function,epochs):

        self.model=model
        self.optimizer=optimizer
        self.loss_function=loss_function
        self.epochs=epochs

    def train(self,X_train,Y_train):

        y_train=torch.from_numpy(Y_train.astype(int)).type(torch.LongTensor)
        tot_loss=0.0
        all_preds=[]

        for t in range(self.epochs):
            epoch_loss = 0.0

            #model.train()
            y_pred=self.model(A, create_features(graph))
            all_preds.append(y_pred)
            loss = self.loss_function(y_pred[X_train], y_train)
            self.optimizer.zero_grad()
            epoch_loss+=loss
            tot_loss+=loss
            loss.backward()
            self.optimizer.step()

            print(str(t),'epoch_loss:'+str(epoch_loss),'total loss:'+str(tot_loss))

        self.all_preds=all_preds

    def test(self,X_test,Y_test):

        self.model.eval()
        y_test=torch.from_numpy(Y_test.astype(int)).type(torch.LongTensor)
        y_pred=self.all_preds[-1]  # preds of last epoch
        loss_test = self.loss_function(y_pred[X_test],y_test)
        print('validation loss is equal to: '+str(loss_test))

    def visualize_classification(self,graph,Y_test,classification):
        last_epoch = self.all_preds[self.epochs-1].detach().numpy() # get outputs of last epoch
        predicted_class = np.argmax(last_epoch, axis=-1) # take the unit with the higher probability
        color = np.where(predicted_class==0, 'c', 'r')
        pos = nx.kamada_kawai_layout(graph)
        nx.draw_networkx(graph, pos, node_color=color, with_labels=True, node_size=300)
        if classification==True:
            print(classification_report(predicted_class[1:-1],Y_test))

# %% [markdown]
# ## Run GCN

# %%
graph=create_graphs_with_attributes('lab2_edgelist.txt','lab2_attributes.csv')
A = np.array(nx.to_numpy_array(graph)) # adjadjency matrix
X_train,Y_train,X_test,Y_test= create_train_test(graph)

model=GCN(inputs_shape=create_features(graph).shape[1],outputs_shape=4,n_classes=2,activation='Relu')
trainer = Trainer(
    model,
    optimizer = optim.Adam(model.parameters(), lr=0.01),
    loss_function=F.cross_entropy,
    epochs=250
)

trainer.train(X_train,Y_train)
trainer.test(X_test,Y_test)
trainer.visualize_classification(graph,Y_test,classification=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1553: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# 0 epoch_loss:tensor(0.7745, grad_fn=<AddBackward0>) total loss:tensor(0.7745, grad_fn=<AddBackward0>)
# 1 epoch_loss:tensor(0.7367, grad_fn=<AddBackward0>) total loss:tensor(1.5113, grad_fn=<AddBackward0>)
# 2 epoch_loss:tensor(0.6940, grad_fn=<AddBackward0>) total loss:tensor(2.2053, grad_fn=<AddBackward0>)
# 3 epoch_loss:tensor(0.6536, grad_fn=<AddBackward0>) total loss:tensor(2.8589, grad_fn=<AddBackward0>)
# 4 epoch_loss:tensor(0.6229, grad_fn=<AddBackward0>) total loss:tensor(3.4818, grad_fn=<AddBackward0>)
# 5 epoch_loss:tensor(0.6049, grad_fn=<AddBackward0>) total loss:tensor(4.0868, grad_fn=<AddBackward0>)
# 6 epoch_loss:tensor(0.5975, grad_fn=<AddBackward0>) total loss:tensor(4.6842, grad_fn=<AddBackward0>)
# 7 epoch_loss:tensor(0.5963, grad_fn=<AddBackward0>) total loss:tensor(5.2805, grad_fn=<AddBackward0>)
# 8 epoch_loss:tensor(0.5977, grad_fn=<AddBackward0>) total loss:tensor(5.8781, grad_fn=<AddBackward0>)
# 9 epoch_loss:tensor(0.5993, grad_fn=<AddBackward0>) total loss:tensor(6.4775, grad_fn=<AddBackward0>)
# 10 epoch_loss:tensor(0.6000, grad_fn=<AddBackward0>) total loss:tensor(7.0775, grad_fn=<AddBackward0>)
# 11 epoch_loss:tensor(0.5993, grad_fn=<AddBackward0>) total loss:tensor(7.6768, grad_fn=<AddBackward0>)
# 12 epoch_loss:tensor(0.5969, grad_fn=<AddBackward0>) total loss:tensor(8.2737, grad_fn=<AddBackward0>)
# 13 epoch_loss:tensor(0.5931, grad_fn=<AddBackward0>) total loss:tensor(8.8668, grad_fn=<AddBackward0>)
# 14 epoch_loss:tensor(0.5878, grad_fn=<AddBackward0>) total loss:tensor(9.4546, grad_fn=<AddBackward0>)
# 15 epoch_loss:tensor(0.5815, grad_fn=<AddBackward0>) total loss:tensor(10.0361, grad_fn=<AddBackward0>)
# 16 epoch_loss:tensor(0.5744, grad_fn=<AddBackward0>) total loss:tensor(10.6106, grad_fn=<AddBackward0>)
# 17 epoch_loss:tensor(0.5669, grad_fn=<AddBackward0>) total loss:tensor(11.1774, grad_fn=<AddBackward0>)
# 18 epoch_loss:tensor(0.5592, grad_fn=<AddBackward0>) total loss:tensor(11.7366, grad_fn=<AddBackward0>)
# 19 epoch_loss:tensor(0.5519, grad_fn=<AddBackward0>) total loss:tensor(12.2885, grad_fn=<AddBackward0>)
# 20 epoch_loss:tensor(0.5451, grad_fn=<AddBackward0>) total loss:tensor(12.8336, grad_fn=<AddBackward0>)
# 21 epoch_loss:tensor(0.5393, grad_fn=<AddBackward0>) total loss:tensor(13.3729, grad_fn=<AddBackward0>)
# 22 epoch_loss:tensor(0.5343, grad_fn=<AddBackward0>) total loss:tensor(13.9072, grad_fn=<AddBackward0>)
# 23 epoch_loss:tensor(0.5302, grad_fn=<AddBackward0>) total loss:tensor(14.4375, grad_fn=<AddBackward0>)
# 24 epoch_loss:tensor(0.5267, grad_fn=<AddBackward0>) total loss:tensor(14.9642, grad_fn=<AddBackward0>)
# 25 epoch_loss:tensor(0.5234, grad_fn=<AddBackward0>) total loss:tensor(15.4876, grad_fn=<AddBackward0>)
# 26 epoch_loss:tensor(0.5199, grad_fn=<AddBackward0>) total loss:tensor(16.0076, grad_fn=<AddBackward0>)
# 27 epoch_loss:tensor(0.5159, grad_fn=<AddBackward0>) total loss:tensor(16.5235, grad_fn=<AddBackward0>)
# 28 epoch_loss:tensor(0.5113, grad_fn=<AddBackward0>) total loss:tensor(17.0349, grad_fn=<AddBackward0>)
# 29 epoch_loss:tensor(0.5061, grad_fn=<AddBackward0>) total loss:tensor(17.5410, grad_fn=<AddBackward0>)
# 30 epoch_loss:tensor(0.5005, grad_fn=<AddBackward0>) total loss:tensor(18.0414, grad_fn=<AddBackward0>)
# 31 epoch_loss:tensor(0.4946, grad_fn=<AddBackward0>) total loss:tensor(18.5361, grad_fn=<AddBackward0>)
# 32 epoch_loss:tensor(0.4888, grad_fn=<AddBackward0>) total loss:tensor(19.0249, grad_fn=<AddBackward0>)
# 33 epoch_loss:tensor(0.4832, grad_fn=<AddBackward0>) total loss:tensor(19.5080, grad_fn=<AddBackward0>)
# 34 epoch_loss:tensor(0.4778, grad_fn=<AddBackward0>) total loss:tensor(19.9858, grad_fn=<AddBackward0>)
# 35 epoch_loss:tensor(0.4727, grad_fn=<AddBackward0>) total loss:tensor(20.4586, grad_fn=<AddBackward0>)
# 36 epoch_loss:tensor(0.4679, grad_fn=<AddBackward0>) total loss:tensor(20.9265, grad_fn=<AddBackward0>)
# 37 epoch_loss:tensor(0.4632, grad_fn=<AddBackward0>) total loss:tensor(21.3897, grad_fn=<AddBackward0>)
# 38 epoch_loss:tensor(0.4586, grad_fn=<AddBackward0>) total loss:tensor(21.8484, grad_fn=<AddBackward0>)
# 39 epoch_loss:tensor(0.4540, grad_fn=<AddBackward0>) total loss:tensor(22.3024, grad_fn=<AddBackward0>)
# 40 epoch_loss:tensor(0.4493, grad_fn=<AddBackward0>) total loss:tensor(22.7517, grad_fn=<AddBackward0>)
# 41 epoch_loss:tensor(0.4446, grad_fn=<AddBackward0>) total loss:tensor(23.1963, grad_fn=<AddBackward0>)
# 42 epoch_loss:tensor(0.4398, grad_fn=<AddBackward0>) total loss:tensor(23.6361, grad_fn=<AddBackward0>)
# 43 epoch_loss:tensor(0.4350, grad_fn=<AddBackward0>) total loss:tensor(24.0711, grad_fn=<AddBackward0>)
# 44 epoch_loss:tensor(0.4302, grad_fn=<AddBackward0>) total loss:tensor(24.5013, grad_fn=<AddBackward0>)
# 45 epoch_loss:tensor(0.4255, grad_fn=<AddBackward0>) total loss:tensor(24.9269, grad_fn=<AddBackward0>)
# 46 epoch_loss:tensor(0.4210, grad_fn=<AddBackward0>) total loss:tensor(25.3478, grad_fn=<AddBackward0>)
# 47 epoch_loss:tensor(0.4165, grad_fn=<AddBackward0>) total loss:tensor(25.7644, grad_fn=<AddBackward0>)
# 48 epoch_loss:tensor(0.4122, grad_fn=<AddBackward0>) total loss:tensor(26.1766, grad_fn=<AddBackward0>)
# 49 epoch_loss:tensor(0.4081, grad_fn=<AddBackward0>) total loss:tensor(26.5847, grad_fn=<AddBackward0>)
# 50 epoch_loss:tensor(0.4042, grad_fn=<AddBackward0>) total loss:tensor(26.9889, grad_fn=<AddBackward0>)
# 51 epoch_loss:tensor(0.4004, grad_fn=<AddBackward0>) total loss:tensor(27.3893, grad_fn=<AddBackward0>)
# 52 epoch_loss:tensor(0.3967, grad_fn=<AddBackward0>) total loss:tensor(27.7860, grad_fn=<AddBackward0>)
# 53 epoch_loss:tensor(0.3931, grad_fn=<AddBackward0>) total loss:tensor(28.1791, grad_fn=<AddBackward0>)
# 54 epoch_loss:tensor(0.3897, grad_fn=<AddBackward0>) total loss:tensor(28.5688, grad_fn=<AddBackward0>)
# 55 epoch_loss:tensor(0.3863, grad_fn=<AddBackward0>) total loss:tensor(28.9550, grad_fn=<AddBackward0>)
# 56 epoch_loss:tensor(0.3830, grad_fn=<AddBackward0>) total loss:tensor(29.3381, grad_fn=<AddBackward0>)
# 57 epoch_loss:tensor(0.3799, grad_fn=<AddBackward0>) total loss:tensor(29.7180, grad_fn=<AddBackward0>)
# 58 epoch_loss:tensor(0.3769, grad_fn=<AddBackward0>) total loss:tensor(30.0949, grad_fn=<AddBackward0>)
# 59 epoch_loss:tensor(0.3740, grad_fn=<AddBackward0>) total loss:tensor(30.4689, grad_fn=<AddBackward0>)
# 60 epoch_loss:tensor(0.3713, grad_fn=<AddBackward0>) total loss:tensor(30.8402, grad_fn=<AddBackward0>)
# 61 epoch_loss:tensor(0.3686, grad_fn=<AddBackward0>) total loss:tensor(31.2088, grad_fn=<AddBackward0>)
# 62 epoch_loss:tensor(0.3661, grad_fn=<AddBackward0>) total loss:tensor(31.5749, grad_fn=<AddBackward0>)
# 63 epoch_loss:tensor(0.3638, grad_fn=<AddBackward0>) total loss:tensor(31.9387, grad_fn=<AddBackward0>)
# 64 epoch_loss:tensor(0.3615, grad_fn=<AddBackward0>) total loss:tensor(32.3002, grad_fn=<AddBackward0>)
# 65 epoch_loss:tensor(0.3594, grad_fn=<AddBackward0>) total loss:tensor(32.6596, grad_fn=<AddBackward0>)
# 66 epoch_loss:tensor(0.3574, grad_fn=<AddBackward0>) total loss:tensor(33.0170, grad_fn=<AddBackward0>)
# 67 epoch_loss:tensor(0.3555, grad_fn=<AddBackward0>) total loss:tensor(33.3725, grad_fn=<AddBackward0>)
# 68 epoch_loss:tensor(0.3536, grad_fn=<AddBackward0>) total loss:tensor(33.7261, grad_fn=<AddBackward0>)
# 69 epoch_loss:tensor(0.3519, grad_fn=<AddBackward0>) total loss:tensor(34.0780, grad_fn=<AddBackward0>)
# 70 epoch_loss:tensor(0.3503, grad_fn=<AddBackward0>) total loss:tensor(34.4283, grad_fn=<AddBackward0>)
# 71 epoch_loss:tensor(0.3487, grad_fn=<AddBackward0>) total loss:tensor(34.7770, grad_fn=<AddBackward0>)
# 72 epoch_loss:tensor(0.3472, grad_fn=<AddBackward0>) total loss:tensor(35.1242, grad_fn=<AddBackward0>)
# 73 epoch_loss:tensor(0.3458, grad_fn=<AddBackward0>) total loss:tensor(35.4700, grad_fn=<AddBackward0>)
# 74 epoch_loss:tensor(0.3445, grad_fn=<AddBackward0>) total loss:tensor(35.8145, grad_fn=<AddBackward0>)
# 75 epoch_loss:tensor(0.3432, grad_fn=<AddBackward0>) total loss:tensor(36.1577, grad_fn=<AddBackward0>)
# 76 epoch_loss:tensor(0.3420, grad_fn=<AddBackward0>) total loss:tensor(36.4997, grad_fn=<AddBackward0>)
# 77 epoch_loss:tensor(0.3409, grad_fn=<AddBackward0>) total loss:tensor(36.8406, grad_fn=<AddBackward0>)
# 78 epoch_loss:tensor(0.3398, grad_fn=<AddBackward0>) total loss:tensor(37.1804, grad_fn=<AddBackward0>)
# 79 epoch_loss:tensor(0.3388, grad_fn=<AddBackward0>) total loss:tensor(37.5192, grad_fn=<AddBackward0>)
# 80 epoch_loss:tensor(0.3378, grad_fn=<AddBackward0>) total loss:tensor(37.8570, grad_fn=<AddBackward0>)
# 81 epoch_loss:tensor(0.3369, grad_fn=<AddBackward0>) total loss:tensor(38.1939, grad_fn=<AddBackward0>)
# 82 epoch_loss:tensor(0.3361, grad_fn=<AddBackward0>) total loss:tensor(38.5300, grad_fn=<AddBackward0>)
# 83 epoch_loss:tensor(0.3352, grad_fn=<AddBackward0>) total loss:tensor(38.8652, grad_fn=<AddBackward0>)
# 84 epoch_loss:tensor(0.3345, grad_fn=<AddBackward0>) total loss:tensor(39.1997, grad_fn=<AddBackward0>)
# 85 epoch_loss:tensor(0.3337, grad_fn=<AddBackward0>) total loss:tensor(39.5334, grad_fn=<AddBackward0>)
# 86 epoch_loss:tensor(0.3330, grad_fn=<AddBackward0>) total loss:tensor(39.8664, grad_fn=<AddBackward0>)
# 87 epoch_loss:tensor(0.3324, grad_fn=<AddBackward0>) total loss:tensor(40.1987, grad_fn=<AddBackward0>)
# 88 epoch_loss:tensor(0.3317, grad_fn=<AddBackward0>) total loss:tensor(40.5305, grad_fn=<AddBackward0>)
# 89 epoch_loss:tensor(0.3311, grad_fn=<AddBackward0>) total loss:tensor(40.8616, grad_fn=<AddBackward0>)
# 90 epoch_loss:tensor(0.3305, grad_fn=<AddBackward0>) total loss:tensor(41.1921, grad_fn=<AddBackward0>)
# 91 epoch_loss:tensor(0.3300, grad_fn=<AddBackward0>) total loss:tensor(41.5221, grad_fn=<AddBackward0>)
# 92 epoch_loss:tensor(0.3295, grad_fn=<AddBackward0>) total loss:tensor(41.8516, grad_fn=<AddBackward0>)
# 93 epoch_loss:tensor(0.3290, grad_fn=<AddBackward0>) total loss:tensor(42.1806, grad_fn=<AddBackward0>)
# 94 epoch_loss:tensor(0.3285, grad_fn=<AddBackward0>) total loss:tensor(42.5091, grad_fn=<AddBackward0>)
# 95 epoch_loss:tensor(0.3281, grad_fn=<AddBackward0>) total loss:tensor(42.8372, grad_fn=<AddBackward0>)
# 96 epoch_loss:tensor(0.3276, grad_fn=<AddBackward0>) total loss:tensor(43.1648, grad_fn=<AddBackward0>)
# 97 epoch_loss:tensor(0.3272, grad_fn=<AddBackward0>) total loss:tensor(43.4920, grad_fn=<AddBackward0>)
# 98 epoch_loss:tensor(0.3268, grad_fn=<AddBackward0>) total loss:tensor(43.8189, grad_fn=<AddBackward0>)
# 99 epoch_loss:tensor(0.3265, grad_fn=<AddBackward0>) total loss:tensor(44.1453, grad_fn=<AddBackward0>)
# 100 epoch_loss:tensor(0.3261, grad_fn=<AddBackward0>) total loss:tensor(44.4714, grad_fn=<AddBackward0>)
# 101 epoch_loss:tensor(0.3258, grad_fn=<AddBackward0>) total loss:tensor(44.7972, grad_fn=<AddBackward0>)
# 102 epoch_loss:tensor(0.3254, grad_fn=<AddBackward0>) total loss:tensor(45.1226, grad_fn=<AddBackward0>)
# 103 epoch_loss:tensor(0.3251, grad_fn=<AddBackward0>) total loss:tensor(45.4477, grad_fn=<AddBackward0>)
# 104 epoch_loss:tensor(0.3248, grad_fn=<AddBackward0>) total loss:tensor(45.7726, grad_fn=<AddBackward0>)
# 105 epoch_loss:tensor(0.3245, grad_fn=<AddBackward0>) total loss:tensor(46.0971, grad_fn=<AddBackward0>)
# 106 epoch_loss:tensor(0.3242, grad_fn=<AddBackward0>) total loss:tensor(46.4213, grad_fn=<AddBackward0>)
# 107 epoch_loss:tensor(0.3240, grad_fn=<AddBackward0>) total loss:tensor(46.7453, grad_fn=<AddBackward0>)
# 108 epoch_loss:tensor(0.3237, grad_fn=<AddBackward0>) total loss:tensor(47.0690, grad_fn=<AddBackward0>)
# 109 epoch_loss:tensor(0.3235, grad_fn=<AddBackward0>) total loss:tensor(47.3925, grad_fn=<AddBackward0>)
# 110 epoch_loss:tensor(0.3232, grad_fn=<AddBackward0>) total loss:tensor(47.7158, grad_fn=<AddBackward0>)
# 111 epoch_loss:tensor(0.3230, grad_fn=<AddBackward0>) total loss:tensor(48.0388, grad_fn=<AddBackward0>)
# 112 epoch_loss:tensor(0.3228, grad_fn=<AddBackward0>) total loss:tensor(48.3616, grad_fn=<AddBackward0>)
# 113 epoch_loss:tensor(0.3226, grad_fn=<AddBackward0>) total loss:tensor(48.6842, grad_fn=<AddBackward0>)
# 114 epoch_loss:tensor(0.3224, grad_fn=<AddBackward0>) total loss:tensor(49.0065, grad_fn=<AddBackward0>)
# 115 epoch_loss:tensor(0.3222, grad_fn=<AddBackward0>) total loss:tensor(49.3287, grad_fn=<AddBackward0>)
# 116 epoch_loss:tensor(0.3220, grad_fn=<AddBackward0>) total loss:tensor(49.6507, grad_fn=<AddBackward0>)
# 117 epoch_loss:tensor(0.3218, grad_fn=<AddBackward0>) total loss:tensor(49.9725, grad_fn=<AddBackward0>)
# 118 epoch_loss:tensor(0.3216, grad_fn=<AddBackward0>) total loss:tensor(50.2941, grad_fn=<AddBackward0>)
# 119 epoch_loss:tensor(0.3215, grad_fn=<AddBackward0>) total loss:tensor(50.6156, grad_fn=<AddBackward0>)
# 120 epoch_loss:tensor(0.3213, grad_fn=<AddBackward0>) total loss:tensor(50.9369, grad_fn=<AddBackward0>)
# 121 epoch_loss:tensor(0.3211, grad_fn=<AddBackward0>) total loss:tensor(51.2580, grad_fn=<AddBackward0>)
# 122 epoch_loss:tensor(0.3210, grad_fn=<AddBackward0>) total loss:tensor(51.5790, grad_fn=<AddBackward0>)
# 123 epoch_loss:tensor(0.3208, grad_fn=<AddBackward0>) total loss:tensor(51.8998, grad_fn=<AddBackward0>)
# 124 epoch_loss:tensor(0.3207, grad_fn=<AddBackward0>) total loss:tensor(52.2205, grad_fn=<AddBackward0>)
# 125 epoch_loss:tensor(0.3205, grad_fn=<AddBackward0>) total loss:tensor(52.5411, grad_fn=<AddBackward0>)
# 126 epoch_loss:tensor(0.3204, grad_fn=<AddBackward0>) total loss:tensor(52.8615, grad_fn=<AddBackward0>)
# 127 epoch_loss:tensor(0.3203, grad_fn=<AddBackward0>) total loss:tensor(53.1817, grad_fn=<AddBackward0>)
# 128 epoch_loss:tensor(0.3201, grad_fn=<AddBackward0>) total loss:tensor(53.5019, grad_fn=<AddBackward0>)
# 129 epoch_loss:tensor(0.3200, grad_fn=<AddBackward0>) total loss:tensor(53.8219, grad_fn=<AddBackward0>)
# 130 epoch_loss:tensor(0.3199, grad_fn=<AddBackward0>) total loss:tensor(54.1418, grad_fn=<AddBackward0>)
# 131 epoch_loss:tensor(0.3198, grad_fn=<AddBackward0>) total loss:tensor(54.4616, grad_fn=<AddBackward0>)
# 132 epoch_loss:tensor(0.3197, grad_fn=<AddBackward0>) total loss:tensor(54.7813, grad_fn=<AddBackward0>)
# 133 epoch_loss:tensor(0.3196, grad_fn=<AddBackward0>) total loss:tensor(55.1008, grad_fn=<AddBackward0>)
# 134 epoch_loss:tensor(0.3195, grad_fn=<AddBackward0>) total loss:tensor(55.4203, grad_fn=<AddBackward0>)
# 135 epoch_loss:tensor(0.3193, grad_fn=<AddBackward0>) total loss:tensor(55.7396, grad_fn=<AddBackward0>)
# 136 epoch_loss:tensor(0.3192, grad_fn=<AddBackward0>) total loss:tensor(56.0589, grad_fn=<AddBackward0>)
# 137 epoch_loss:tensor(0.3191, grad_fn=<AddBackward0>) total loss:tensor(56.3780, grad_fn=<AddBackward0>)
# 138 epoch_loss:tensor(0.3190, grad_fn=<AddBackward0>) total loss:tensor(56.6971, grad_fn=<AddBackward0>)
# 139 epoch_loss:tensor(0.3190, grad_fn=<AddBackward0>) total loss:tensor(57.0160, grad_fn=<AddBackward0>)
# 140 epoch_loss:tensor(0.3189, grad_fn=<AddBackward0>) total loss:tensor(57.3349, grad_fn=<AddBackward0>)
# 141 epoch_loss:tensor(0.3188, grad_fn=<AddBackward0>) total loss:tensor(57.6536, grad_fn=<AddBackward0>)
# 142 epoch_loss:tensor(0.3187, grad_fn=<AddBackward0>) total loss:tensor(57.9723, grad_fn=<AddBackward0>)
# 143 epoch_loss:tensor(0.3186, grad_fn=<AddBackward0>) total loss:tensor(58.2909, grad_fn=<AddBackward0>)
# 144 epoch_loss:tensor(0.3185, grad_fn=<AddBackward0>) total loss:tensor(58.6095, grad_fn=<AddBackward0>)
# 145 epoch_loss:tensor(0.3184, grad_fn=<AddBackward0>) total loss:tensor(58.9279, grad_fn=<AddBackward0>)
# 146 epoch_loss:tensor(0.3184, grad_fn=<AddBackward0>) total loss:tensor(59.2463, grad_fn=<AddBackward0>)
# 147 epoch_loss:tensor(0.3183, grad_fn=<AddBackward0>) total loss:tensor(59.5646, grad_fn=<AddBackward0>)
# 148 epoch_loss:tensor(0.3182, grad_fn=<AddBackward0>) total loss:tensor(59.8828, grad_fn=<AddBackward0>)
# 149 epoch_loss:tensor(0.3181, grad_fn=<AddBackward0>) total loss:tensor(60.2009, grad_fn=<AddBackward0>)
# 150 epoch_loss:tensor(0.3181, grad_fn=<AddBackward0>) total loss:tensor(60.5190, grad_fn=<AddBackward0>)
# 151 epoch_loss:tensor(0.3180, grad_fn=<AddBackward0>) total loss:tensor(60.8370, grad_fn=<AddBackward0>)
# 152 epoch_loss:tensor(0.3179, grad_fn=<AddBackward0>) total loss:tensor(61.1549, grad_fn=<AddBackward0>)
# 153 epoch_loss:tensor(0.3179, grad_fn=<AddBackward0>) total loss:tensor(61.4728, grad_fn=<AddBackward0>)
# 154 epoch_loss:tensor(0.3178, grad_fn=<AddBackward0>) total loss:tensor(61.7906, grad_fn=<AddBackward0>)
# 155 epoch_loss:tensor(0.3177, grad_fn=<AddBackward0>) total loss:tensor(62.1084, grad_fn=<AddBackward0>)
# 156 epoch_loss:tensor(0.3177, grad_fn=<AddBackward0>) total loss:tensor(62.4261, grad_fn=<AddBackward0>)
# 157 epoch_loss:tensor(0.3176, grad_fn=<AddBackward0>) total loss:tensor(62.7437, grad_fn=<AddBackward0>)
# 158 epoch_loss:tensor(0.3176, grad_fn=<AddBackward0>) total loss:tensor(63.0613, grad_fn=<AddBackward0>)
# 159 epoch_loss:tensor(0.3175, grad_fn=<AddBackward0>) total loss:tensor(63.3788, grad_fn=<AddBackward0>)
# 160 epoch_loss:tensor(0.3175, grad_fn=<AddBackward0>) total loss:tensor(63.6962, grad_fn=<AddBackward0>)
# 161 epoch_loss:tensor(0.3174, grad_fn=<AddBackward0>) total loss:tensor(64.0136, grad_fn=<AddBackward0>)
# 162 epoch_loss:tensor(0.3173, grad_fn=<AddBackward0>) total loss:tensor(64.3310, grad_fn=<AddBackward0>)
# 163 epoch_loss:tensor(0.3173, grad_fn=<AddBackward0>) total loss:tensor(64.6482, grad_fn=<AddBackward0>)
# 164 epoch_loss:tensor(0.3172, grad_fn=<AddBackward0>) total loss:tensor(64.9655, grad_fn=<AddBackward0>)
# 165 epoch_loss:tensor(0.3172, grad_fn=<AddBackward0>) total loss:tensor(65.2827, grad_fn=<AddBackward0>)
# 166 epoch_loss:tensor(0.3171, grad_fn=<AddBackward0>) total loss:tensor(65.5998, grad_fn=<AddBackward0>)
# 167 epoch_loss:tensor(0.3171, grad_fn=<AddBackward0>) total loss:tensor(65.9169, grad_fn=<AddBackward0>)
# 168 epoch_loss:tensor(0.3170, grad_fn=<AddBackward0>) total loss:tensor(66.2339, grad_fn=<AddBackward0>)
# 169 epoch_loss:tensor(0.3170, grad_fn=<AddBackward0>) total loss:tensor(66.5509, grad_fn=<AddBackward0>)
# 170 epoch_loss:tensor(0.3169, grad_fn=<AddBackward0>) total loss:tensor(66.8679, grad_fn=<AddBackward0>)
# 171 epoch_loss:tensor(0.3169, grad_fn=<AddBackward0>) total loss:tensor(67.1848, grad_fn=<AddBackward0>)
# 172 epoch_loss:tensor(0.3169, grad_fn=<AddBackward0>) total loss:tensor(67.5016, grad_fn=<AddBackward0>)
# 173 epoch_loss:tensor(0.3168, grad_fn=<AddBackward0>) total loss:tensor(67.8185, grad_fn=<AddBackward0>)
# 174 epoch_loss:tensor(0.3168, grad_fn=<AddBackward0>) total loss:tensor(68.1352, grad_fn=<AddBackward0>)
# 175 epoch_loss:tensor(0.3167, grad_fn=<AddBackward0>) total loss:tensor(68.4520, grad_fn=<AddBackward0>)
# 176 epoch_loss:tensor(0.3167, grad_fn=<AddBackward0>) total loss:tensor(68.7686, grad_fn=<AddBackward0>)
# 177 epoch_loss:tensor(0.3167, grad_fn=<AddBackward0>) total loss:tensor(69.0853, grad_fn=<AddBackward0>)
# 178 epoch_loss:tensor(0.3166, grad_fn=<AddBackward0>) total loss:tensor(69.4019, grad_fn=<AddBackward0>)
# 179 epoch_loss:tensor(0.3166, grad_fn=<AddBackward0>) total loss:tensor(69.7185, grad_fn=<AddBackward0>)
# 180 epoch_loss:tensor(0.3165, grad_fn=<AddBackward0>) total loss:tensor(70.0350, grad_fn=<AddBackward0>)
# 181 epoch_loss:tensor(0.3165, grad_fn=<AddBackward0>) total loss:tensor(70.3515, grad_fn=<AddBackward0>)
# 182 epoch_loss:tensor(0.3165, grad_fn=<AddBackward0>) total loss:tensor(70.6680, grad_fn=<AddBackward0>)
# 183 epoch_loss:tensor(0.3164, grad_fn=<AddBackward0>) total loss:tensor(70.9844, grad_fn=<AddBackward0>)
# 184 epoch_loss:tensor(0.3164, grad_fn=<AddBackward0>) total loss:tensor(71.3008, grad_fn=<AddBackward0>)
# 185 epoch_loss:tensor(0.3164, grad_fn=<AddBackward0>) total loss:tensor(71.6171, grad_fn=<AddBackward0>)
# 186 epoch_loss:tensor(0.3163, grad_fn=<AddBackward0>) total loss:tensor(71.9335, grad_fn=<AddBackward0>)
# 187 epoch_loss:tensor(0.3163, grad_fn=<AddBackward0>) total loss:tensor(72.2497, grad_fn=<AddBackward0>)
# 188 epoch_loss:tensor(0.3163, grad_fn=<AddBackward0>) total loss:tensor(72.5660, grad_fn=<AddBackward0>)
# 189 epoch_loss:tensor(0.3162, grad_fn=<AddBackward0>) total loss:tensor(72.8822, grad_fn=<AddBackward0>)
# 190 epoch_loss:tensor(0.3162, grad_fn=<AddBackward0>) total loss:tensor(73.1984, grad_fn=<AddBackward0>)
# 191 epoch_loss:tensor(0.3162, grad_fn=<AddBackward0>) total loss:tensor(73.5146, grad_fn=<AddBackward0>)
# 192 epoch_loss:tensor(0.3161, grad_fn=<AddBackward0>) total loss:tensor(73.8307, grad_fn=<AddBackward0>)
# 193 epoch_loss:tensor(0.3161, grad_fn=<AddBackward0>) total loss:tensor(74.1468, grad_fn=<AddBackward0>)
# 194 epoch_loss:tensor(0.3161, grad_fn=<AddBackward0>) total loss:tensor(74.4628, grad_fn=<AddBackward0>)
# 195 epoch_loss:tensor(0.3160, grad_fn=<AddBackward0>) total loss:tensor(74.7789, grad_fn=<AddBackward0>)
# 196 epoch_loss:tensor(0.3160, grad_fn=<AddBackward0>) total loss:tensor(75.0949, grad_fn=<AddBackward0>)
# 197 epoch_loss:tensor(0.3160, grad_fn=<AddBackward0>) total loss:tensor(75.4109, grad_fn=<AddBackward0>)
# 198 epoch_loss:tensor(0.3160, grad_fn=<AddBackward0>) total loss:tensor(75.7268, grad_fn=<AddBackward0>)
# 199 epoch_loss:tensor(0.3159, grad_fn=<AddBackward0>) total loss:tensor(76.0427, grad_fn=<AddBackward0>)
# 200 epoch_loss:tensor(0.3159, grad_fn=<AddBackward0>) total loss:tensor(76.3586, grad_fn=<AddBackward0>)
# 201 epoch_loss:tensor(0.3159, grad_fn=<AddBackward0>) total loss:tensor(76.6745, grad_fn=<AddBackward0>)
# 202 epoch_loss:tensor(0.3158, grad_fn=<AddBackward0>) total loss:tensor(76.9903, grad_fn=<AddBackward0>)
# 203 epoch_loss:tensor(0.3158, grad_fn=<AddBackward0>) total loss:tensor(77.3062, grad_fn=<AddBackward0>)
# 204 epoch_loss:tensor(0.3158, grad_fn=<AddBackward0>) total loss:tensor(77.6220, grad_fn=<AddBackward0>)
# 205 epoch_loss:tensor(0.3158, grad_fn=<AddBackward0>) total loss:tensor(77.9377, grad_fn=<AddBackward0>)
# 206 epoch_loss:tensor(0.3157, grad_fn=<AddBackward0>) total loss:tensor(78.2535, grad_fn=<AddBackward0>)
# 207 epoch_loss:tensor(0.3157, grad_fn=<AddBackward0>) total loss:tensor(78.5692, grad_fn=<AddBackward0>)
# 208 epoch_loss:tensor(0.3157, grad_fn=<AddBackward0>) total loss:tensor(78.8849, grad_fn=<AddBackward0>)
# 209 epoch_loss:tensor(0.3157, grad_fn=<AddBackward0>) total loss:tensor(79.2005, grad_fn=<AddBackward0>)
# 210 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(79.5162, grad_fn=<AddBackward0>)
# 211 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(79.8318, grad_fn=<AddBackward0>)
# 212 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(80.1474, grad_fn=<AddBackward0>)
# 213 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(80.4630, grad_fn=<AddBackward0>)
# 214 epoch_loss:tensor(0.3156, grad_fn=<AddBackward0>) total loss:tensor(80.7785, grad_fn=<AddBackward0>)
# 215 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(81.0941, grad_fn=<AddBackward0>)
# 216 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(81.4096, grad_fn=<AddBackward0>)
# 217 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(81.7251, grad_fn=<AddBackward0>)
# 218 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(82.0406, grad_fn=<AddBackward0>)
# 219 epoch_loss:tensor(0.3155, grad_fn=<AddBackward0>) total loss:tensor(82.3560, grad_fn=<AddBackward0>)
# 220 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(82.6714, grad_fn=<AddBackward0>)
# 221 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(82.9869, grad_fn=<AddBackward0>)
# 222 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(83.3023, grad_fn=<AddBackward0>)
# 223 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(83.6176, grad_fn=<AddBackward0>)
# 224 epoch_loss:tensor(0.3154, grad_fn=<AddBackward0>) total loss:tensor(83.9330, grad_fn=<AddBackward0>)
# 225 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(84.2483, grad_fn=<AddBackward0>)
# 226 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(84.5636, grad_fn=<AddBackward0>)
# 227 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(84.8789, grad_fn=<AddBackward0>)
# 228 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(85.1942, grad_fn=<AddBackward0>)
# 229 epoch_loss:tensor(0.3153, grad_fn=<AddBackward0>) total loss:tensor(85.5095, grad_fn=<AddBackward0>)
# 230 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(85.8247, grad_fn=<AddBackward0>)
# 231 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(86.1400, grad_fn=<AddBackward0>)
# 232 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(86.4552, grad_fn=<AddBackward0>)
# 233 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(86.7704, grad_fn=<AddBackward0>)
# 234 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(87.0855, grad_fn=<AddBackward0>)
# 235 epoch_loss:tensor(0.3152, grad_fn=<AddBackward0>) total loss:tensor(87.4007, grad_fn=<AddBackward0>)
# 236 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(87.7159, grad_fn=<AddBackward0>)
# 237 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(88.0310, grad_fn=<AddBackward0>)
# 238 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(88.3461, grad_fn=<AddBackward0>)
# 239 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(88.6612, grad_fn=<AddBackward0>)
# 240 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(88.9763, grad_fn=<AddBackward0>)
# 241 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(89.2914, grad_fn=<AddBackward0>)
# 242 epoch_loss:tensor(0.3151, grad_fn=<AddBackward0>) total loss:tensor(89.6064, grad_fn=<AddBackward0>)
# 243 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(89.9215, grad_fn=<AddBackward0>)
# 244 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(90.2365, grad_fn=<AddBackward0>)
# 245 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(90.5515, grad_fn=<AddBackward0>)
# 246 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(90.8665, grad_fn=<AddBackward0>)
# 247 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(91.1815, grad_fn=<AddBackward0>)
# 248 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(91.4965, grad_fn=<AddBackward0>)
# 249 epoch_loss:tensor(0.3150, grad_fn=<AddBackward0>) total loss:tensor(91.8114, grad_fn=<AddBackward0>)
# validation loss is equal to: tensor(0.5559, grad_fn=<NllLossBackward0>)
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        18
#            1       0.88      1.00      0.93        14
#
#     accuracy                           0.94        32
#    macro avg       0.94      0.94      0.94        32
# weighted avg       0.95      0.94      0.94        32
